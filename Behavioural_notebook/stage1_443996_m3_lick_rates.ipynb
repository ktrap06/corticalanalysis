# %% [markdown]
# # stage1_443996_m3_lick_rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array)

# %%
stage = "stage1"
file_data = select_folder(stage)
lick_rate = licking(file_data, stage)
# Out:
# Selected folder: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates
# 10
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day10_2024-02-22_11-44-05_data.txt
# 11
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day11_2024-02-23_12-51-12_data.txt
# 1
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day1_2024-02-13_16-31-17_data.txt
# 2
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day2_2024-02-14_15-19-05_data.txt
# 3
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day3_2024-02-15_13-40-33_data.txt
# 4
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day4_2024-02-16_11-38-52_data.txt
# 5
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day5_2024-02-17_12-41-55_data.txt
# 6
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day6_2024-02-18_13-02-27_data.txt
# 7
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day7_2024-02-19_11-34-31_data.txt
# 8
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day8_2024-02-20_11-27-00_data.txt
# 9
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates\443996_m3_stage1_day9_2024-02-21_10-41-33_data.txt
# Processing complete.
# Stage 1 day 10 reached a lick rate of 100.0%
# Stage 1 day 11 reached a lick rate of 67.0%
# Stage 1 day 1 reached a lick rate of 47.0%
# Stage 1 day 2 reached a lick rate of 1.0%
# Stage 1 day 3 reached a lick rate of 4.0%
# Stage 1 day 4 reached a lick rate of 3.0%
# Stage 1 day 5 reached a lick rate of 78.0%
# Stage 1 day 6 reached a lick rate of 65.0%
# Stage 1 day 7 reached a lick rate of 62.0%
# Stage 1 day 8 reached a lick rate of 88.0%
# Stage 1 day 9 reached a lick rate of 33.0%

# %%
plot_array(lick_rate,stage)
