# %% [markdown]
# # stage1_443996_m3_lick_rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os
import re

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array)

# %%
stage = "stage1"
cage = "443996"
mouse = "m3"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day10_2024-02-22_11-44-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day11_2024-02-23_12-51-12_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day12_2024-02-24_11-25-24_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day13_2024-02-26_13-22-36_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day14_2024-02-27_15-49-23_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day1_2024-02-13_16-31-17_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day2_2024-02-14_15-19-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day3_2024-02-15_13-40-33_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day4_2024-02-16_11-38-52_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day5_2024-02-17_12-41-55_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day6_2024-02-18_13-02-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day7_2024-02-19_11-34-31_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day8_2024-02-20_11-27-00_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443996/stage1_443996_m3/lick_rates/443996_m3_stage1_day9_2024-02-21_10-41-33_data.txt
# Stage 1 day 10 reached a lick rate of 100.0%
# Stage 1 day 11 reached a lick rate of 67.0%
# Stage 1 day 12 reached a lick rate of 58.0%
# Stage 1 day 13 reached a lick rate of 57.0%
# Stage 1 day 14 reached a lick rate of 69.0%
# Stage 1 day 1 reached a lick rate of 47.0%
# Stage 1 day 2 reached a lick rate of 1.0%
# Stage 1 day 3 reached a lick rate of 4.0%
# Stage 1 day 4 reached a lick rate of 3.0%
# Stage 1 day 5 reached a lick rate of 78.0%
# Stage 1 day 6 reached a lick rate of 65.0%
# Stage 1 day 7 reached a lick rate of 62.0%
# Stage 1 day 8 reached a lick rate of 88.0%
# Stage 1 day 9 reached a lick rate of 33.0%

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
