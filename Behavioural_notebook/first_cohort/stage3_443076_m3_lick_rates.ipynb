# %% [markdown]
# # stage3_443076_m3 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total)

# %%
stage = "stage3"
cage = "443076"
mouse = "m3"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day10_2024-04-09_12-44-32_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day11_2024-04-10_14-12-39_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day12_2024-04-11_15-23-02_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day13_2024-04-12_12-54-53_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day14_2024-04-15_13-09-59_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day15_2024-04-16_13-28-26_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day16_2024-04-17_14-02-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day17_2024-04-18_12-30-52_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day18_2024-04-19_12-47-11_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day19_2024-04-23_16-58-10_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day1_2024-02-24_10-54-08_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day2_2024-02-27_16-44-47_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day3_2024-02-28_15-21-25_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day4_2024-03-06_12-50-30_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day5_2024-03-07_13-00-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day6_2024-03-08_16-44-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day7_2024-03-13_13-10-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day8_2024-03-14_14-46-45_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m3/lick_rates/443076_m3_stage3_day9_2024-03-15_13-19-17_data.txt
# Stage 3 day 10 success left: 16.94915254237288%, success right:46.875%, fail: left stim right lick
# total successful trials 27.472527472527474
# Stage 3 day 11 success left: 100.0%, success right:0.0%, fail: left stim right lick
# total successful trials 28.000000000000004
# Stage 3 day 12 success left: 100.0%, success right:0.0%, fail: left stim right lick
# total successful trials 37.0
# Stage 3 day 13 success left: 33.9622641509434%, success right:44.680851063829785%, fail: left stim right lick
# total successful trials 39.0
# Stage 3 day 14 success left: 100.0%, success right:0.0%, fail: left stim right lick
# total successful trials 28.999999999999996
# Stage 3 day 15 success left: 20.8955223880597%, success right:81.81818181818183%, fail: left stim right lick
# total successful trials 41.0
# Stage 3 day 16 success left: 47.27272727272727%, success right:60.0%, fail: left stim right lick
# total successful trials 53.0
# Stage 3 day 17 success left: 54.054054054054056%, success right:33.33333333333333%, fail: left stim right lick
# total successful trials 41.0
# Stage 3 day 18 success left: 100.0%, success right:1.4705882352941175%, fail: left stim right lick
# total successful trials 33.0
# Stage 3 day 19 success left: 71.05263157894737%, success right:17.741935483870968%, fail: left stim right lick
# total successful trials 38.0
# Stage 3 day 1 success left: 100.0%, success right:0.0%, fail: left stim right lick
# total successful trials 16.0
# Stage 3 day 2 success left: 20.967741935483872%, success right:60.526315789473685%, fail: left stim right lick
# total successful trials 36.0
# Stage 3 day 3 success left: 95.0%, success right:6.25%, fail: left stim right lick
# total successful trials 24.0
# Stage 3 day 4 success left: 100.0%, success right:1.1627906976744187%, fail: left stim right lick
# total successful trials 15.0
# Stage 3 day 5 success left: 45.0%, success right:38.333333333333336%, fail: left stim right lick
# total successful trials 41.0
# Stage 3 day 6 success left: 16.176470588235293%, success right:68.75%, fail: left stim right lick
# total successful trials 33.0
# Stage 3 day 7 success left: 100.0%, success right:0.0%, fail: left stim right lick
# total successful trials 14.000000000000002
# Stage 3 day 8 success left: 100.0%, success right:2.4096385542168677%, fail: left stim right lick
# total successful trials 19.0
# Stage 3 day 9 success left: 92.85714285714286%, success right:4.651162790697675%, fail: left stim right lick
# total successful trials 17.0

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
