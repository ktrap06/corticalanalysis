# %% [markdown]
# # stage3_443076_m1 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total)

# %%
stage = "stage3"
cage = "443076"
mouse = "m1"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day10_2024-03-15_12-56-25_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day11_2024-04-09_13-09-06_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day12_2024-04-10_13-46-18_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day13_2024-04-11_14-58-55_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day14_2024-04-12_13-19-14_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day15_2024-04-15_12-44-31_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day16_2024-04-16_13-52-06_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day17_2024-04-17_14-24-52_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day18_2024-04-18_12-09-00_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day19_2024-04-19_12-24-31_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day1_2024-02-23_15-04-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day20_2024-04-23_16-36-01_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day2_2024-02-24_10-30-33_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day3_2024-02-27_16-18-38_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day4_2024-02-28_16-36-46_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day5_2024-03-06_12-18-42_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day6_2024-03-07_12-37-32_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day7_2024-03-08_17-12-22_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day8_2024-03-13_12-44-43_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates/443076_m1_stage3_day9_2024-03-14_15-50-06_data.txt
# Stage 3 day 10 success left: 58.139534883720934%, success right:28.07017543859649%, fail: left stim right lick
# total successful trials 41.0
# Stage 3 day 11 success left: 16.3265306122449%, success right:58.82352941176471%, fail: left stim right lick
# total successful trials 38.0
# Stage 3 day 12 success left: 29.411764705882355%, success right:75.0%, fail: left stim right lick
# total successful trials 44.0
# Stage 3 day 13 success left: 96.55172413793103%, success right:0.0%, fail: left stim right lick
# total successful trials 28.000000000000004
# Stage 3 day 14 success left: 22.727272727272727%, success right:70.58823529411765%, fail: left stim right lick
# total successful trials 39.0
# Stage 3 day 15 success left: 50.0%, success right:70.45454545454545%, fail: left stim right lick
# total successful trials 59.0
# Stage 3 day 16 success left: 35.9375%, success right:55.55555555555556%, fail: left stim right lick
# total successful trials 43.0
# Stage 3 day 17 success left: 55.00000000000001%, success right:40.0%, fail: left stim right lick
# total successful trials 46.0
# Stage 3 day 18 success left: 0.0%, success right:100.0%, fail: left stim right lick
# total successful trials 28.999999999999996
# Stage 3 day 19 success left: 66.66666666666666%, success right:12.857142857142856%, fail: left stim right lick
# total successful trials 28.999999999999993
# Stage 3 day 1 success left: 1.2195121951219512%, success right:94.44444444444444%, fail: left stim right lick
# total successful trials 18.0
# Stage 3 day 20 success left: 100.0%, success right:14.084507042253522%, fail: left stim right lick
# total successful trials 39.0
# Stage 3 day 2 success left: 1.1764705882352942%, success right:100.0%, fail: left stim right lick
# total successful trials 16.0
# Stage 3 day 3 success left: 93.33333333333333%, success right:2.3529411764705883%, fail: left stim right lick
# total successful trials 16.0
# Stage 3 day 4 success left: 36.76470588235294%, success right:43.75%, fail: left stim right lick
# total successful trials 39.0
# Stage 3 day 5 success left: 0.0%, success right:100.0%, fail: left stim right lick
# total successful trials 15.151515151515152
# Stage 3 day 6 success left: 36.36363636363637%, success right:33.33333333333333%, fail: left stim right lick
# total successful trials 35.0
# Stage 3 day 7 success left: 68.18181818181817%, success right:15.384615384615385%, fail: left stim right lick
# total successful trials 27.0
# Stage 3 day 8 success left: 25.31645569620253%, success right:76.19047619047619%, fail: left stim right lick
# total successful trials 36.0
# Stage 3 day 9 success left: 24.137931034482758%, success right:57.14285714285714%, fail: left stim right lick
# total successful trials 38.0

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
def plot_total(array, stage, export_path_total=None):
    # Extract x and y values from the array
    x_values = [row[0] for row in array]
    if stage == "stage2":
        y_values = [row[3] for row in array]
    elif stage == "stage3":
        y_values = [row[7] for row in array]
    else:
        raise ValueError("Invalid stage. Must be 'stage2' or 'stage3'.")

    # Create the figure and axes
    fig, ax = plt.subplots(figsize=(4, 3))
    
    # Change the figure and axes background colors
    fig.patch.set_facecolor('#F3F6F1')
    ax.set_facecolor('#F3F6F1')

    # Plot the data
    ax.plot(x_values, y_values, marker='o', linestyle='-', color='#589370', label='Lick rate', linewidth=2.5)
    # Add the threshold line
    #threshold = np.zeros(len(array)) + 75
    #ax.plot(x_values, threshold, linestyle='dotted', color='y', label='Threshold')

    # Add labels and title
    ax.set_xlabel('Day Number')
    ax.set_ylabel('Percent Licked (%)')
    ax.set_title('WT Stage 3', fontsize=18)
    
    # Set y-axis limit and ticks
    y_max = 110
    y_ticks = np.linspace(0, 100, num=6)
    ax.set_ylim(0, y_max)
    ax.set_yticks(y_ticks)
    ax.spines['top'].set_visible(False) #hides the top spine.
    ax.spines['right'].set_visible(False) #hides the right spine.
    
    # Set x-axis ticks
    x_ticks = np.linspace(1, len(x_values), num=7, dtype=int)  # Set ticks based on the number of data points
    ax.set_xticks(x_ticks)
    ax.set_xlabel('Day Number', fontsize=16)
    ax.set_ylabel('Percent Success (%)', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)


    # Add legend and grid
    #ax.legend()
    #ax.grid(False, which='both', linestyle='--', linewidth=0.5)

    plt.tight_layout()
    
    if export_path_total:
        plt.savefig(export_path_total)  # Save the plot if a save path is provided
    else:
        plt.show()
        
    return fig

plot_total(sorted(lick_rate),stage, export_path_total)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
