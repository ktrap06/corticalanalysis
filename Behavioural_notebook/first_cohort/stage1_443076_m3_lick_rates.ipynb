# %% [markdown]
# # stage1_443076_m3 licking rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array)

# %%
stage = "stage1"
folder = select_folder(stage)
file_data, directory = folder[0], folder[1]
lick_rate = licking(file_data, stage)
# Out:
# Selected folder: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage1_443076_m3/lick_rates
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage1_443076_m3/lick_rates\443076_m3_stage1_day1_2024-02-13_16-01-20_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage1_443076_m3/lick_rates\443076_m3_stage1_day2_2024-02-14_15-56-12_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage1_443076_m3/lick_rates\443076_m3_stage1_day3_2024-02-15_14-37-55_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage1_443076_m3/lick_rates\443076_m3_stage1_day4_2024-02-16_10-36-53_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage1_443076_m3/lick_rates\443076_m3_stage1_day5_2024-02-17_12-54-05_data.txt
# Processing complete.
# Stage 1 day 1 reached a lick rate of 37.0%
# Stage 1 day 2 reached a lick rate of 66.0%
# Stage 1 day 3 reached a lick rate of 84.0%
# Stage 1 day 4 reached a lick rate of 95.0%
# Stage 1 day 5 reached a lick rate of 91.0%

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}.png"
plot = plot_array(sorted(lick_rate),stage, export_path)
