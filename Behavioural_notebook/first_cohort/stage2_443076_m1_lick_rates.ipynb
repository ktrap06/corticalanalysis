# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total,
                                    plot_total_pretty)

# %%
stage = "stage2"
cage = "443076"
mouse = "m1"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m1/lick_rates/443076_m1_stage2_day1_2024-02-18_13-59-32_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m1/lick_rates/443076_m1_stage2_day2_2024-02-19_12-59-01_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m1/lick_rates/443076_m1_stage2_day3_2024-02-20_13-41-56_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m1/lick_rates/443076_m1_stage2_day4_2024-02-21_11-40-35_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m1/lick_rates/443076_m1_stage2_day5_2024-02-22_10-18-12_data.txt
# Stage 2 day 1 reached left lick rate of 68.33333333333333% successful, and right lick rate of 97.5% successful
# total successful trials 80.0
# Stage 2 day 2 reached left lick rate of 87.5% successful, and right lick rate of 72.72727272727273% successful
# total successful trials 81.0
# Stage 2 day 3 reached left lick rate of 96.42857142857143% successful, and right lick rate of 100.0% successful
# total successful trials 98.0
# Stage 2 day 4 reached left lick rate of 100.0% successful, and right lick rate of 75.80645161290323% successful
# total successful trials 85.0
# Stage 2 day 5 reached left lick rate of 100.0% successful, and right lick rate of 100.0% successful
# total successful trials 100.0

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
def plot_total(array, stage, export_path_total=None):
    # Extract x and y values from the array
    x_values = [row[0] for row in array]
    if stage == "stage2":
        y_values = [row[3] for row in array]
    elif stage == "stage3":
        y_values = [row[7] for row in array]
    else:
        y_values = [row[1] for row in array]

    # Create the figure and axes
    fig, ax = plt.subplots(figsize=(4, 3))
    
    # Change the figure and axes background colors
    fig.patch.set_facecolor('#F3F6F1')
    ax.set_facecolor('#F3F6F1')

    # Plot the data
    ax.plot(x_values, y_values, marker='o', linestyle='-', color='#589370', label='Lick rate', linewidth=2.5)
    # Add the threshold line
    #threshold = np.zeros(len(array)) + 75
    #ax.plot(x_values, threshold, linestyle='dotted', color='y', label='Threshold')

    # Add labels and title
    ax.set_xlabel('Day Number')
    ax.set_ylabel('Percent Licked (%)')
    ax.set_title('WT Stage 2', fontsize=18)
    
    # Set y-axis limit and ticks
    y_max = 110
    y_ticks = np.linspace(0, 100, num=6)
    ax.set_ylim(0, y_max)
    ax.set_yticks(y_ticks)
    ax.spines['top'].set_visible(False) #hides the top spine.
    ax.spines['right'].set_visible(False) #hides the right spine.
    
    # Set x-axis ticks
    x_ticks = np.linspace(1, len(x_values), num=5, dtype=int)  # Set ticks based on the number of data points
    ax.set_xticks(x_ticks)
    ax.set_xlabel('Day Number', fontsize=16)
    ax.set_ylabel('Percent Licked (%)', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)


    # Add legend and grid
    #ax.legend()
    #ax.grid(False, which='both', linestyle='--', linewidth=0.5)

    plt.tight_layout()
    
    if export_path_total:
        plt.savefig(export_path_total)  # Save the plot if a save path is provided
    else:
        plt.show()
        
    return fig

plot_total(sorted(lick_rate),stage, export_path)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
