# %% [markdown]
# # stage 3 male averaged

# %%
import numpy as np
import subprocess
import matplotlib.pyplot as plt
import pandas as pd

from functions_lick_rates import (plot_averaged)

# %%
HD_mouse = ['443076_m1','443996_m5']
WT_mouse = ['443076_m3']

# %%
'''
# Combine both HD and WT mice
all_mice = HD_mouse + WT_mouse

# Loop through each mouse and execute the corresponding notebook
for mouse in all_mice:
    notebook_name = f"stage2_{mouse}_lick_rates.ipynb"
    
    # Run the notebook and save the executed version as 'executed_notebook_'
    command = f'jupyter nbconvert --to notebook --execute {notebook_name} --output executed_{notebook_name}'
    
    # Execute the command
    subprocess.run(command, shell=True)

print("All notebooks executed successfully.")
'''
# Out:
# '\n# Combine both HD and WT mice\nall_mice = HD_mouse + WT_mouse\n\n# Loop through each mouse and execute the corresponding notebook\nfor mouse in all_mice:\n    notebook_name = f"stage2_{mouse}_lick_rates.ipynb"\n    \n    # Run the notebook and save the executed version as \'executed_notebook_\'\n    command = f\'jupyter nbconvert --to notebook --execute {notebook_name} --output executed_{notebook_name}\'\n    \n    # Execute the command\n    subprocess.run(command, shell=True)\n\nprint("All notebooks executed successfully.")\n'

# %% [markdown]
# # HD averaged

# %%
# List to hold dataframes
HD_data_list = []

# Load the .npy data for each mouse (HD)
for mouse in HD_mouse:
    file_path = f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_stage3_{mouse}.npy"
    try:
        # Load the .npy file into a numpy array
        data = np.load(file_path)
        
        # Create a DataFrame from the data
        HD_df = pd.DataFrame(data, columns=['day_number', 'one', 'two', 'three', 'four', 'five', 'six', 'total'])
        
        # Append the dataframe to the list
        HD_data_list.append(HD_df)
    except FileNotFoundError:
        print(f"File not found: {file_path}")

# Concatenate all dataframes into a single dataframe
all_HD_data = pd.concat(HD_data_list)

# Group by 'day_number' and calculate the mean for each column (except 'day_number')
average_HD_data = all_HD_data.groupby('day_number').mean().reset_index()

# Optionally, you can save the average data to a CSV file
average_HD_data.to_csv("X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/averaged/stage3_HD_male_average.csv", index=False)

# Print the averaged data
print(average_HD_data)
# Out:
#     day_number         one         two       three       four       five  \
# 0          1.0    0.609756   97.222222   99.390244   2.777778   0.000000
# 1          2.0    0.588235   97.500000   97.536765   0.000000   2.500000
# 2          3.0   60.751174   37.383367   39.248826  62.616633   0.000000
# 3          4.0   44.023379   40.727459   55.976621  57.633197   2.564103
# 4          5.0   38.888889   51.369863   50.000000  42.465753  27.777778
# 5          6.0   26.289926   49.358974   71.683047  50.641026   2.027027
# 6          7.0   38.952020   48.763736   58.775253  51.236264   2.272727
# 7          8.0   14.173379   83.683473   79.766015  13.375350   7.575758
# 8          9.0   47.595281   35.023041   51.088929  63.364055   3.947368
# 9         10.0   76.505665   16.494104   22.212284  79.407535   7.692308
# 10        11.0   10.402071   71.836007   86.810844  26.203209   4.827901
# 11        12.0   63.354531   38.293651   34.439587  60.143849   2.941176
# 12        13.0   48.275862   46.551724   48.907237  51.019913   5.245265
# 13        14.0   12.144886   83.905229   84.730114  14.705882   3.906250
# 14        15.0   25.000000   80.681818   71.268657  14.772727   5.970149
# 15        16.0   17.968750   76.666667   82.031250  23.333333   0.000000
# 16        17.0   27.500000   68.387097   71.050725  30.000000   2.173913
# 17        18.0    0.000000  100.000000  100.000000   0.000000   0.000000
# 18        19.0   66.666667   12.857143   26.666667  82.857143  16.666667
# 19        20.0  100.000000   14.084507    0.000000  85.915493   0.000000
#
#           six      total
# 0    0.000000  18.000000
# 1   10.000000  17.500000
# 2    0.000000  28.500000
# 3    1.639344  41.000000
# 4   10.273973  19.075758
# 5    5.769231  32.000000
# 6    0.641026  28.500000
# 7   14.705882  34.500000
# 8    2.419355  36.500000
# 9    4.918033  40.500000
# 10   5.436720  34.500000
# 11   6.250000  40.500000
# 12   9.324915  27.500000
# 13   6.944444  37.500000
# 14  12.121212  44.500000
# 15   0.000000  43.500000
# 16   4.838710  38.000000
# 17   0.000000  29.000000
# 18   7.142857  29.000000
# 19   0.000000  39.000000

# %%
plot_averaged(average_HD_data, condition="HD", nogo = "FALSE", export_path_nogo=f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/exported_figures/stage3_male_HD_averaged_lick_rates.png", dpi =300)

# %% [markdown]
# # WT averaged

# %%
# List to hold dataframes
WT_data_list = []

# Load the .npy data for each mouse (HD)
for mouse in WT_mouse:
    file_path = f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_stage3_{mouse}.npy"
    try:
        # Load the .npy file into a numpy array
        WT_data = np.load(file_path)
        
        # Create a DataFrame from the data
        WT_df = pd.DataFrame(WT_data, columns=['day_number', 'one', 'two', 'three', 'four', 'five', 'six', 'total'])
        
        # Append the dataframe to the list
        WT_data_list.append(WT_df)
    except FileNotFoundError:
        print(f"File not found: {file_path}")

# Concatenate all dataframes into a single dataframe
all_WT_data = pd.concat(WT_data_list)

# Group by 'day_number' and calculate the mean for each column (except 'day_number')
average_WT_data = all_WT_data.groupby('day_number').mean().reset_index()

# Optionally, you can save the average data to a CSV file
average_WT_data.to_csv("X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/averaged/stage3_WT_male_average.csv", index=False)

# Print the averaged data
print(average_WT_data)
# Out:
#     day_number         one        two      three        four      five  \
# 0          1.0  100.000000   0.000000   0.000000  100.000000  0.000000
# 1          2.0   20.967742  60.526316  79.032258   39.473684  0.000000
# 2          3.0   95.000000   6.250000   5.000000   93.750000  0.000000
# 3          4.0  100.000000   1.162791   0.000000   97.674419  7.142857
# 4          5.0   45.000000  38.333333  55.000000   61.666667  0.000000
# 5          6.0   16.176471  68.750000  83.823529   31.250000  0.000000
# 6          7.0  100.000000   0.000000   0.000000  100.000000  0.000000
# 7          8.0  100.000000   2.409639   0.000000   97.590361  0.000000
# 8          9.0   92.857143   4.651163   7.142857   95.348837  0.000000
# 9         10.0   16.949153  46.875000  77.966102   46.875000  8.474576
# 10        11.0  100.000000   0.000000   0.000000  100.000000  0.000000
# 11        12.0  100.000000   0.000000   0.000000  100.000000  0.000000
# 12        13.0   33.962264  44.680851  66.037736   55.319149  0.000000
# 13        14.0  100.000000   0.000000   0.000000  100.000000  0.000000
# 14        15.0   20.895522  81.818182  79.104478   15.151515  1.492537
# 15        16.0   47.272727  60.000000  52.727273   40.000000  0.000000
# 16        17.0   54.054054  33.333333  45.945946   66.666667  0.000000
# 17        18.0  100.000000   1.470588   0.000000   98.529412  0.000000
# 18        19.0   71.052632  17.741935  28.947368   82.258065  0.000000
#
#           six      total
# 0    0.000000  16.000000
# 1    0.000000  36.000000
# 2    0.000000  24.000000
# 3    1.162791  15.000000
# 4    0.000000  41.000000
# 5    0.000000  33.000000
# 6    0.000000  14.000000
# 7    0.000000  19.000000
# 8    0.000000  17.000000
# 9   15.625000  27.472527
# 10   0.000000  28.000000
# 11   0.000000  37.000000
# 12   0.000000  39.000000
# 13   0.000000  29.000000
# 14   3.030303  41.000000
# 15   0.000000  53.000000
# 16   0.000000  41.000000
# 17   0.000000  33.000000
# 18   0.000000  38.000000

# %%
plot_averaged(average_WT_data, condition="WT", nogo = "FALSE", export_path_nogo=f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/exported_figures/stage3_male_WT_averaged_lick_rates.png", dpi=300)
