# %% [markdown]
# # stage2_443076_m3 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total)

# %%
stage = "stage2"
folder = select_folder(stage)
file_data, directory = folder[0], folder[1]
lick_rate = licking(file_data, stage)
# Out:
# Selected folder: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m3/lick_rates
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m3/lick_rates\443076_m3_stage2_day1_2024-02-18_14-25-41_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m3/lick_rates\443076_m3_stage2_day2_2024-02-19_12-27-24_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m3/lick_rates\443076_m3_stage2_day3_2024-02-20_13-11-21_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m3/lick_rates\443076_m3_stage2_day4_2024-02-21_11-13-07_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m3/lick_rates\443076_m3_stage2_day5_2024-02-22_10-47-12_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage2_443076_m3/lick_rates\443076_m3_stage2_day6_2024-02-23_13-48-22_data.txt
# Processing complete.
# Stage 2 day 1 reached left lick rate of 77.55102040816327%, and right lick rate of 66.66666666666666%
# Stage 2 day 2 reached left lick rate of 71.42857142857143%, and right lick rate of 49.01960784313725%
# Stage 2 day 3 reached left lick rate of 73.68421052631578%, and right lick rate of 45.16129032258064%
# Stage 2 day 4 reached left lick rate of 97.72727272727273%, and right lick rate of 71.42857142857143%
# Stage 2 day 5 reached left lick rate of 98.24561403508771%, and right lick rate of 90.69767441860465%
# Stage 2 day 6 reached left lick rate of 85.41666666666666%, and right lick rate of 80.76923076923077%

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)
