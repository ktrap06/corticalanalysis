# %% [markdown]
# # stage2_475165_f7 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total,
                                    plot_array_nogo,
                                    plot_total_nogo,
                                    plot_total_pretty)

# %%
stage = "stage2"
cage = "475165"
mouse = "f7"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day10_2024-09-06_14-48-15_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day11_2024-09-10_11-23-59_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day12_2024-09-11_13-12-56_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day13_2024-09-12_14-45-48_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day14_2024-09-18_15-17-20_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day15_2024-09-19_13-44-01_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day1_2024-08-09_15-03-31_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day2_2024-08-13_14-27-28_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day3_2024-08-14_16-13-28_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day4_2024-08-15_14-32-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day5_2024-08-16_14-27-25_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day6_2024-08-25_11-36-03_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day7_2024-08-26_09-48-07_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day8_2024-09-04_14-54-31_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f7/lick_rates/475165_f7_stage2_day9_2024-09-05_12-50-23_data.txt
# Stage 2 day 10 reached left lick rate of 78.37837837837837% successful, and right lick rate of 97.5609756097561% successful
# Stage 2 day 10 reached left nogo rate of 18.181818181818183% successful, and right nogo rate of 0.0% successful
# total successful trials 88.46153846153845
# total successful nogo trials 9.090909090909092
# Stage 2 day 11 reached left lick rate of 34.285714285714285% successful, and right lick rate of 64.44444444444444% successful
# Stage 2 day 11 reached left nogo rate of 50.0% successful, and right nogo rate of 60.0% successful
# total successful trials 51.24999999999999
# total successful nogo trials 55.00000000000001
# Stage 2 day 12 reached left lick rate of 51.162790697674424% successful, and right lick rate of 67.64705882352942% successful
# Stage 2 day 12 reached left nogo rate of 27.27272727272727% successful, and right nogo rate of 50.0% successful
# total successful trials 58.44155844155845
# total successful nogo trials 39.130434782608695
# Stage 2 day 13 reached left lick rate of 64.51612903225806% successful, and right lick rate of 75.0% successful
# Stage 2 day 13 reached left nogo rate of 22.22222222222222% successful, and right nogo rate of 12.5% successful
# total successful trials 71.08433734939759
# total successful nogo trials 17.647058823529413
# Stage 2 day 14 reached left lick rate of 75.67567567567568% successful, and right lick rate of 97.22222222222221% successful
# Stage 2 day 14 reached left nogo rate of 50.0% successful, and right nogo rate of 5.88235294117647% successful
# total successful trials 86.30136986301369
# total successful nogo trials 22.22222222222222
# Stage 2 day 15 reached left lick rate of 71.11111111111111% successful, and right lick rate of 80.48780487804879% successful
# Stage 2 day 15 reached left nogo rate of 40.0% successful, and right nogo rate of 22.22222222222222% successful
# total successful trials 75.5813953488372
# total successful nogo trials 28.57142857142857
# Stage 2 day 1 reached left lick rate of 100.0% successful, and right lick rate of 98.0% successful
# Stage 2 day 1 reached left nogo rate of 0.0% successful, and right nogo rate of 0.0% successful
# total successful trials 98.83720930232558
# total successful nogo trials 0.0
# Stage 2 day 2 reached left lick rate of 93.47826086956522% successful, and right lick rate of 84.84848484848484% successful
# Stage 2 day 2 reached left nogo rate of 27.27272727272727% successful, and right nogo rate of 20.0% successful
# total successful trials 89.87341772151899
# total successful nogo trials 23.809523809523807
# Stage 2 day 3 reached left lick rate of 91.11111111111111% successful, and right lick rate of 91.66666666666666% successful
# Stage 2 day 3 reached left nogo rate of 14.285714285714285% successful, and right nogo rate of 0.0% successful
# total successful trials 91.35802469135803
# total successful nogo trials 10.526315789473683
# Stage 2 day 4 reached left lick rate of 95.34883720930233% successful, and right lick rate of 100.0% successful
# Stage 2 day 4 reached left nogo rate of 10.0% successful, and right nogo rate of 0.0% successful
# total successful trials 97.59036144578313
# total successful nogo trials 5.88235294117647
# Stage 2 day 5 reached left lick rate of 90.0% successful, and right lick rate of 67.44186046511628% successful
# Stage 2 day 5 reached left nogo rate of 0.0% successful, and right nogo rate of 11.11111111111111% successful
# total successful trials 78.3132530120482
# total successful nogo trials 5.88235294117647
# Stage 2 day 6 reached left lick rate of 70.0% successful, and right lick rate of 54.347826086956516% successful
# Stage 2 day 6 reached left nogo rate of 11.11111111111111% successful, and right nogo rate of 20.0% successful
# total successful trials 61.627906976744185
# total successful nogo trials 14.285714285714285
# Stage 2 day 7 reached left lick rate of 67.5% successful, and right lick rate of 64.86486486486487% successful
# Stage 2 day 7 reached left nogo rate of 33.33333333333333% successful, and right nogo rate of 54.54545454545454% successful
# total successful trials 66.23376623376623
# total successful nogo trials 43.47826086956521
# Stage 2 day 8 reached left lick rate of 92.85714285714286% successful, and right lick rate of 90.69767441860465% successful
# Stage 2 day 8 reached left nogo rate of 0.0% successful, and right nogo rate of 20.0% successful
# total successful trials 91.76470588235294
# total successful nogo trials 13.333333333333334
# Stage 2 day 9 reached left lick rate of 85.71428571428571% successful, and right lick rate of 87.87878787878788% successful
# Stage 2 day 9 reached left nogo rate of 33.33333333333333% successful, and right nogo rate of 33.33333333333333% successful
# total successful trials 86.88524590163934
# total successful nogo trials 33.33333333333333

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
export_path_nogo = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_LR.png"
export_path_nogo_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
if stage == "stage2":
    plot_array_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
if stage == "stage2":
    plot_total_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
plot_total_pretty(sorted(lick_rate),stage, export_path_total)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
