# %% [markdown]
# # stage2_475165_f3 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total,
                                    plot_array_nogo,
                                    plot_total_nogo,
                                    plot_total_pretty)

# %%
stage = "stage2"
cage = "475165"
mouse = "f3"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day11_2024-09-10_10-57-54_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day12_2024-09-11_12-43-30_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day13_2024-09-12_13-49-18_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day1_2024-08-09_14-39-37_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day2_2024-08-13_15-07-24_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day3_2024-08-14_15-49-04_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day4_2024-08-15_15-20-16_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day5_2024-08-16_15-41-34_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day6_2024-08-25_10-11-13_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day7_2024-08-26_10-39-28_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day8_2024-09-04_14-26-20_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f3/lick_rates/475165_f3_stage2_day9_2024-09-05_12-00-59_data.txt
# Stage 2 day 11 reached left lick rate of 24.324324324324326% successful, and right lick rate of 56.09756097560976% successful
# Stage 2 day 11 reached left nogo rate of 70.0% successful, and right nogo rate of 16.666666666666664% successful
# total successful trials 41.02564102564102
# total successful nogo trials 40.909090909090914
# Stage 2 day 12 reached left lick rate of 73.80952380952381% successful, and right lick rate of 75.0% successful
# Stage 2 day 12 reached left nogo rate of 28.57142857142857% successful, and right nogo rate of 25.0% successful
# total successful trials 74.39024390243902
# total successful nogo trials 27.77777777777778
# Stage 2 day 13 reached left lick rate of 18.421052631578945% successful, and right lick rate of 83.33333333333334% successful
# Stage 2 day 13 reached left nogo rate of 75.0% successful, and right nogo rate of 7.142857142857142% successful
# total successful trials 50.0
# total successful nogo trials 38.46153846153847
# Stage 2 day 1 reached left lick rate of 68.42105263157895% successful, and right lick rate of 10.0% successful
# Stage 2 day 1 reached left nogo rate of 7.6923076923076925% successful, and right nogo rate of 77.77777777777779% successful
# total successful trials 38.46153846153847
# total successful nogo trials 36.36363636363637
# Stage 2 day 2 reached left lick rate of 60.0% successful, and right lick rate of 47.91666666666667% successful
# Stage 2 day 2 reached left nogo rate of 66.66666666666666% successful, and right nogo rate of 77.77777777777779% successful
# total successful trials 53.40909090909091
# total successful nogo trials 75.0
# Stage 2 day 3 reached left lick rate of 72.09302325581395% successful, and right lick rate of 72.97297297297297% successful
# Stage 2 day 3 reached left nogo rate of 9.090909090909092% successful, and right nogo rate of 11.11111111111111% successful
# total successful trials 72.5
# total successful nogo trials 10.0
# Stage 2 day 4 reached left lick rate of 67.44186046511628% successful, and right lick rate of 97.22222222222221% successful
# Stage 2 day 4 reached left nogo rate of 10.0% successful, and right nogo rate of 9.090909090909092% successful
# total successful trials 81.01265822784809
# total successful nogo trials 9.523809523809524
# Stage 2 day 5 reached left lick rate of 86.48648648648648% successful, and right lick rate of 88.63636363636364% successful
# Stage 2 day 5 reached left nogo rate of 0.0% successful, and right nogo rate of 33.33333333333333% successful
# total successful trials 87.65432098765432
# total successful nogo trials 15.789473684210522
# Stage 2 day 6 reached left lick rate of 51.35135135135135% successful, and right lick rate of 41.17647058823529% successful
# Stage 2 day 6 reached left nogo rate of 33.33333333333333% successful, and right nogo rate of 33.33333333333333% successful
# total successful trials 45.45454545454545
# total successful nogo trials 33.33333333333333
# Stage 2 day 7 reached left lick rate of 70.0% successful, and right lick rate of 68.42105263157895% successful
# Stage 2 day 7 reached left nogo rate of 28.57142857142857% successful, and right nogo rate of 50.0% successful
# total successful trials 69.23076923076923
# total successful nogo trials 36.36363636363637
# Stage 2 day 8 reached left lick rate of 27.500000000000004% successful, and right lick rate of 100.0% successful
# Stage 2 day 8 reached left nogo rate of 75.0% successful, and right nogo rate of 0.0% successful
# total successful trials 62.82051282051282
# total successful nogo trials 40.909090909090914
# Stage 2 day 9 reached left lick rate of 64.28571428571429% successful, and right lick rate of 33.33333333333333% successful
# Stage 2 day 9 reached left nogo rate of 60.0% successful, and right nogo rate of 66.66666666666666% successful
# total successful trials 49.382716049382715
# total successful nogo trials 63.1578947368421

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
export_path_nogo = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_LR.png"
export_path_nogo_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
if stage == "stage2":
    plot_array_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
if stage == "stage2":
    plot_total_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
plot_total_pretty(sorted(lick_rate),stage, export_path_total)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
