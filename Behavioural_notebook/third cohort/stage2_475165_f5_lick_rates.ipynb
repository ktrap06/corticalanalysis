# %% [markdown]
# # stage2_475165_f5 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total,
                                    plot_array_nogo,
                                    plot_total_nogo,
                                    plot_total_pretty)

# %%
stage = "stage2"
cage = "475165"
mouse = "f5"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day10_2024-09-06_14-23-33_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day11_2024-09-10_10-32-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day12_2024-09-11_13-54-49_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day13_2024-09-12_15-23-34_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day1_2024-08-09_13-49-24_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day2_2024-08-13_15-57-53_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day3_2024-08-14_15-25-42_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day4_2024-08-15_15-42-23_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day5_2024-08-16_15-17-33_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day6_2024-08-25_10-37-06_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day7_2024-08-26_10-14-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day8_2024-09-04_15-54-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f5/lick_rates/475165_f5_stage2_day9_2024-09-05_12-25-33_data.txt
# Stage 2 day 10 reached left lick rate of 50.0% successful, and right lick rate of 65.0% successful
# Stage 2 day 10 reached left nogo rate of 58.333333333333336% successful, and right nogo rate of 60.0% successful
# total successful trials 57.692307692307686
# total successful nogo trials 59.09090909090909
# Stage 2 day 11 reached left lick rate of 39.02439024390244% successful, and right lick rate of 54.285714285714285% successful
# Stage 2 day 11 reached left nogo rate of 80.0% successful, and right nogo rate of 33.33333333333333% successful
# total successful trials 46.05263157894737
# total successful nogo trials 62.5
# Stage 2 day 12 reached left lick rate of 32.55813953488372% successful, and right lick rate of 18.75% successful
# Stage 2 day 12 reached left nogo rate of 76.92307692307693% successful, and right nogo rate of 100.0% successful
# total successful trials 26.666666666666668
# total successful nogo trials 88.0
# Stage 2 day 13 reached left lick rate of 21.052631578947366% successful, and right lick rate of 44.44444444444444% successful
# Stage 2 day 13 reached left nogo rate of 70.0% successful, and right nogo rate of 62.5% successful
# total successful trials 32.432432432432435
# total successful nogo trials 65.38461538461539
# Stage 2 day 1 reached left lick rate of 57.14285714285714% successful, and right lick rate of 48.93617021276596% successful
# Stage 2 day 1 reached left nogo rate of 55.55555555555556% successful, and right nogo rate of 44.44444444444444% successful
# total successful trials 52.4390243902439
# total successful nogo trials 50.0
# Stage 2 day 2 reached left lick rate of 58.82352941176471% successful, and right lick rate of 57.446808510638306% successful
# Stage 2 day 2 reached left nogo rate of 33.33333333333333% successful, and right nogo rate of 50.0% successful
# total successful trials 58.024691358024704
# total successful nogo trials 36.84210526315789
# Stage 2 day 3 reached left lick rate of 71.42857142857143% successful, and right lick rate of 76.08695652173914% successful
# Stage 2 day 3 reached left nogo rate of 33.33333333333333% successful, and right nogo rate of 14.285714285714285% successful
# total successful trials 74.07407407407408
# total successful nogo trials 26.31578947368421
# Stage 2 day 4 reached left lick rate of 70.73170731707317% successful, and right lick rate of 68.57142857142857% successful
# Stage 2 day 4 reached left nogo rate of 38.46153846153847% successful, and right nogo rate of 36.36363636363637% successful
# total successful trials 69.73684210526315
# total successful nogo trials 37.50000000000001
# Stage 2 day 5 reached left lick rate of 97.2972972972973% successful, and right lick rate of 97.43589743589743% successful
# Stage 2 day 5 reached left nogo rate of 0.0% successful, and right nogo rate of 0.0% successful
# total successful trials 97.36842105263158
# total successful nogo trials 0.0
# Stage 2 day 6 reached left lick rate of 60.86956521739131% successful, and right lick rate of 65.0% successful
# Stage 2 day 6 reached left nogo rate of 44.44444444444444% successful, and right nogo rate of 20.0% successful
# total successful trials 62.7906976744186
# total successful nogo trials 35.714285714285715
# Stage 2 day 7 reached left lick rate of 53.65853658536586% successful, and right lick rate of 67.74193548387096% successful
# Stage 2 day 7 reached left nogo rate of 73.33333333333333% successful, and right nogo rate of 46.15384615384615% successful
# total successful trials 59.72222222222222
# total successful nogo trials 60.71428571428571
# Stage 2 day 8 reached left lick rate of 53.84615384615385% successful, and right lick rate of 20.0% successful
# Stage 2 day 8 reached left nogo rate of 57.14285714285714% successful, and right nogo rate of 50.0% successful
# total successful trials 40.229885057471265
# total successful nogo trials 53.84615384615385
# Stage 2 day 9 reached left lick rate of 54.761904761904766% successful, and right lick rate of 54.54545454545454% successful
# Stage 2 day 9 reached left nogo rate of 37.5% successful, and right nogo rate of 55.55555555555556% successful
# total successful trials 54.666666666666664
# total successful nogo trials 44.0

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
export_path_nogo = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_LR.png"
export_path_nogo_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
if stage == "stage2":
    plot_array_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
if stage == "stage2":
    plot_total_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
plot_total_pretty(sorted(lick_rate),stage, export_path_total)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
