# %% [markdown]
# # stage2_466029_f3 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total,
                                    plot_array_nogo,
                                    plot_total_nogo,
                                    plot_total_pretty)

# %%
stage = "stage2"
cage = "466029"
mouse = "f3"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day10_2024-09-06_13-41-34_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day11_2024-09-10_10-06-28_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day12_2024-09-11_12-18-11_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day13_2024-09-12_13-24-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day1_2024-08-09_13-23-43_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day2_2024-08-13_14-02-55_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day3_2024-08-14_14-38-55_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day4_2024-08-15_14-10-57_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day5_2024-08-16_13-59-05_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day6_2024-08-25_09-43-00_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day7_2024-08-26_09-22-48_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day8_2024-09-04_12-42-20_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/466029/stage2_466029_f3/lick_rates/466029_f3_stage2_day9_2024-09-05_11-31-59_data.txt
# Stage 2 day 10 reached left lick rate of 94.87179487179486% successful, and right lick rate of 88.88888888888889% successful
# Stage 2 day 10 reached left nogo rate of 0.0% successful, and right nogo rate of 18.75% successful
# total successful trials 92.0
# total successful nogo trials 12.0
# Stage 2 day 11 reached left lick rate of 91.66666666666666% successful, and right lick rate of 94.5945945945946% successful
# Stage 2 day 11 reached left nogo rate of 6.25% successful, and right nogo rate of 9.090909090909092% successful
# total successful trials 93.15068493150685
# total successful nogo trials 7.4074074074074066
# Stage 2 day 12 reached left lick rate of 100.0% successful, and right lick rate of 89.74358974358975% successful
# Stage 2 day 12 reached left nogo rate of 0.0% successful, and right nogo rate of 18.75% successful
# total successful trials 94.52054794520548
# total successful nogo trials 11.11111111111111
# Stage 2 day 13 reached left lick rate of 0.0% successful, and right lick rate of 92.5925925925926% successful
# Stage 2 day 13 reached left nogo rate of 100.0% successful, and right nogo rate of 14.285714285714285% successful
# total successful trials 31.25
# total successful nogo trials 70.0
# Stage 2 day 1 reached left lick rate of 85.41666666666666% successful, and right lick rate of 0.0% successful
# Stage 2 day 1 reached left nogo rate of 25.0% successful, and right nogo rate of 75.0% successful
# total successful trials 48.80952380952381
# total successful nogo trials 50.0
# Stage 2 day 2 reached left lick rate of 84.84848484848484% successful, and right lick rate of 36.0% successful
# Stage 2 day 2 reached left nogo rate of 11.11111111111111% successful, and right nogo rate of 100.0% successful
# total successful trials 55.42168674698795
# total successful nogo trials 52.94117647058824
# Stage 2 day 3 reached left lick rate of 95.0% successful, and right lick rate of 62.06896551724138% successful
# Stage 2 day 3 reached left nogo rate of 0.0% successful, and right nogo rate of 40.0% successful
# total successful trials 75.51020408163265
# total successful nogo trials 19.047619047619047
# Stage 2 day 4 reached left lick rate of 100.0% successful, and right lick rate of 82.92682926829268% successful
# Stage 2 day 4 reached left nogo rate of 0.0% successful, and right nogo rate of 0.0% successful
# total successful trials 89.55223880597015
# total successful nogo trials 0.0
# Stage 2 day 5 reached left lick rate of 100.0% successful, and right lick rate of 22.5% successful
# Stage 2 day 5 reached left nogo rate of 20.0% successful, and right nogo rate of 81.25% successful
# total successful trials 58.108108108108105
# total successful nogo trials 57.692307692307686
# Stage 2 day 6 reached left lick rate of 100.0% successful, and right lick rate of 42.857142857142854% successful
# Stage 2 day 6 reached left nogo rate of 0.0% successful, and right nogo rate of 57.14285714285714% successful
# total successful trials 71.42857142857143
# total successful nogo trials 25.0
# Stage 2 day 7 reached left lick rate of 100.0% successful, and right lick rate of 93.18181818181817% successful
# Stage 2 day 7 reached left nogo rate of 0.0% successful, and right nogo rate of 7.6923076923076925% successful
# total successful trials 96.29629629629629
# total successful nogo trials 5.263157894736842
# Stage 2 day 8 reached left lick rate of 93.47826086956522% successful, and right lick rate of 97.2972972972973% successful
# Stage 2 day 8 reached left nogo rate of 0.0% successful, and right nogo rate of 0.0% successful
# total successful trials 95.18072289156626
# total successful nogo trials 0.0
# Stage 2 day 9 reached left lick rate of 90.625% successful, and right lick rate of 8.88888888888889% successful
# Stage 2 day 9 reached left nogo rate of 8.333333333333332% successful, and right nogo rate of 72.72727272727273% successful
# total successful trials 42.857142857142854
# total successful nogo trials 39.1304347826087

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
export_path_nogo = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_LR.png"
export_path_nogo_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
if stage == "stage2":
    plot_array_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
if stage == "stage2":
    plot_total_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
plot_total_pretty(sorted(lick_rate),stage, export_path_total)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)

# %%
import numpy as np

# Assuming `lick_rate` is a 2D array or similar structure
np.savetxt(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.csv', 
           lick_rate, 
           delimiter=',', 
           header='Column1,Column2,...',  # replace with your actual column names
           comments='')  # This prevents numpy from adding a comment character (#)
