# %% [markdown]
# # stage2_475165_f1 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total,
                                    plot_array_nogo,
                                    plot_total_nogo,
                                    plot_total_pretty)

# %%
stage = "stage2"
cage = "475165"
mouse = "f1"

# %%
#folder = select_folder(stage) #use this to use pop up to select folder
directory = f"X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/{cage}/{stage}_{cage}_{mouse}/lick_rates/"
file_data = load_files_from_folder(directory, stage)
lick_rate = licking(file_data, stage)
# Out:
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day10_2024-09-06_15-43-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day11_2024-09-10_11-49-35_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day12_2024-09-11_14-20-21_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day13_2024-09-12_14-21-21_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day14_2024-09-18_16-35-50_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day15_2024-09-19_12-58-52_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day1_2024-08-09_14-15-25_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day2_2024-08-13_15-32-24_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day3_2024-08-14_14-59-54_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day4_2024-08-15_14-57-12_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day5_2024-08-16_14-52-54_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day6_2024-08-25_11-00-48_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day7_2024-08-26_11-06-47_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day8_2024-09-04_15-21-27_data.txt
# Loading file: X:/RaymondLab/1_Kai/2_Pi_data/3_third_cohort/475165/stage2_475165_f1/lick_rates/475165_f1_stage2_day9_2024-09-05_13-16-21_data.txt
# Stage 2 day 10 reached left lick rate of 58.139534883720934% successful, and right lick rate of 84.375% successful
# Stage 2 day 10 reached left nogo rate of 56.25% successful, and right nogo rate of 33.33333333333333% successful
# total successful trials 69.33333333333334
# total successful nogo trials 48.0
# Stage 2 day 11 reached left lick rate of 51.28205128205128% successful, and right lick rate of 82.5% successful
# Stage 2 day 11 reached left nogo rate of 40.0% successful, and right nogo rate of 9.090909090909092% successful
# total successful trials 67.08860759493672
# total successful nogo trials 23.809523809523807
# Stage 2 day 12 reached left lick rate of 95.55555555555556% successful, and right lick rate of 93.75% successful
# Stage 2 day 12 reached left nogo rate of 0.0% successful, and right nogo rate of 0.0% successful
# total successful trials 94.8051948051948
# total successful nogo trials 0.0
# Stage 2 day 13 reached left lick rate of 52.27272727272727% successful, and right lick rate of 100.0% successful
# Stage 2 day 13 reached left nogo rate of 38.46153846153847% successful, and right nogo rate of 0.0% successful
# total successful trials 73.75
# total successful nogo trials 25.000000000000007
# Stage 2 day 14 reached left lick rate of 100.0% successful, and right lick rate of 100.0% successful
# Stage 2 day 14 reached left nogo rate of 0.0% successful, and right nogo rate of 0.0% successful
# total successful trials 100.0
# total successful nogo trials 0.0
# Stage 2 day 15 reached left lick rate of 74.28571428571429% successful, and right lick rate of 93.02325581395348% successful
# Stage 2 day 15 reached left nogo rate of 42.857142857142854% successful, and right nogo rate of 0.0% successful
# total successful trials 84.61538461538461
# total successful nogo trials 27.27272727272727
# Stage 2 day 1 reached left lick rate of 100.0% successful, and right lick rate of 75.0% successful
# Stage 2 day 1 reached left nogo rate of 0.0% successful, and right nogo rate of 18.181818181818183% successful
# total successful trials 87.17948717948718
# total successful nogo trials 9.090909090909092
# Stage 2 day 2 reached left lick rate of 93.18181818181817% successful, and right lick rate of 66.66666666666666% successful
# Stage 2 day 2 reached left nogo rate of 25.0% successful, and right nogo rate of 25.0% successful
# total successful trials 81.25
# total successful nogo trials 25.0
# Stage 2 day 3 reached left lick rate of 82.92682926829268% successful, and right lick rate of 79.54545454545455% successful
# Stage 2 day 3 reached left nogo rate of 10.0% successful, and right nogo rate of 0.0% successful
# total successful trials 81.17647058823529
# total successful nogo trials 6.666666666666667
# Stage 2 day 4 reached left lick rate of 59.523809523809526% successful, and right lick rate of 72.09302325581395% successful
# Stage 2 day 4 reached left nogo rate of 80.0% successful, and right nogo rate of 20.0% successful
# total successful trials 65.88235294117646
# total successful nogo trials 40.0
# Stage 2 day 5 reached left lick rate of 80.0% successful, and right lick rate of 68.18181818181817% successful
# Stage 2 day 5 reached left nogo rate of 0.0% successful, and right nogo rate of 30.0% successful
# total successful trials 73.80952380952381
# total successful nogo trials 18.75
# Stage 2 day 6 reached left lick rate of 68.08510638297872% successful, and right lick rate of 29.268292682926827% successful
# Stage 2 day 6 reached left nogo rate of 20.0% successful, and right nogo rate of 71.42857142857143% successful
# total successful trials 50.0
# total successful nogo trials 50.0
# Stage 2 day 7 reached left lick rate of 56.09756097560976% successful, and right lick rate of 59.09090909090909% successful
# Stage 2 day 7 reached left nogo rate of 37.5% successful, and right nogo rate of 42.857142857142854% successful
# total successful trials 57.647058823529406
# total successful nogo trials 40.0
# Stage 2 day 8 reached left lick rate of 88.63636363636364% successful, and right lick rate of 89.1891891891892% successful
# Stage 2 day 8 reached left nogo rate of 12.5% successful, and right nogo rate of 9.090909090909092% successful
# total successful trials 88.88888888888889
# total successful nogo trials 10.526315789473683
# Stage 2 day 9 reached left lick rate of 70.27027027027027% successful, and right lick rate of 73.80952380952381% successful
# Stage 2 day 9 reached left nogo rate of 45.45454545454545% successful, and right nogo rate of 10.0% successful
# total successful trials 72.15189873417721
# total successful nogo trials 28.57142857142857

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
export_path_nogo = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_LR.png"
export_path_nogo_total = f"X:/RaymondLab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_nogo_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)

# %%
if stage == "stage2":
    plot_array_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
if stage == "stage2":
    plot_total_nogo(sorted(lick_rate),stage, export_path_nogo_total)

# %%
plot_total_pretty(sorted(lick_rate),stage, export_path_total)

# %%
np.save(f'X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_{stage}_{cage}_{mouse}.npy', lick_rate)
