# %% [markdown]
# # stage 2 female averaged

# %%
import numpy as np
import subprocess
import matplotlib.pyplot as plt
import pandas as pd

from functions_lick_rates import (plot_averaged)

# %%
HD_mouse = ['466029_f3', '475165_f3', '475165_f7']
WT_mouse = ['475165_f1', '475165_f5']

# %%
'''
# Combine both HD and WT mice
all_mice = HD_mouse + WT_mouse

# Loop through each mouse and execute the corresponding notebook
for mouse in all_mice:
    notebook_name = f"stage2_{mouse}_lick_rates.ipynb"
    
    # Run the notebook and save the executed version as 'executed_notebook_'
    command = f'jupyter nbconvert --to notebook --execute {notebook_name} --output executed_{notebook_name}'
    
    # Execute the command
    subprocess.run(command, shell=True)

print("All notebooks executed successfully.")
'''
# Out:
# '\n# Combine both HD and WT mice\nall_mice = HD_mouse + WT_mouse\n\n# Loop through each mouse and execute the corresponding notebook\nfor mouse in all_mice:\n    notebook_name = f"stage2_{mouse}_lick_rates.ipynb"\n    \n    # Run the notebook and save the executed version as \'executed_notebook_\'\n    command = f\'jupyter nbconvert --to notebook --execute {notebook_name} --output executed_{notebook_name}\'\n    \n    # Execute the command\n    subprocess.run(command, shell=True)\n\nprint("All notebooks executed successfully.")\n'

# %% [markdown]
# # HD averaged

# %%
# List to hold dataframes
HD_data_list = []

# Load the .npy data for each mouse (HD)
for mouse in HD_mouse:
    file_path = f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_stage1_{mouse}.npy"
    try:
        # Load the .npy file into a numpy array
        data = np.load(file_path)
        
        # Create a DataFrame from the data
        HD_df = pd.DataFrame(data, columns=['day_number', 'total'])
        
        # Append the dataframe to the list
        HD_data_list.append(HD_df)
    except FileNotFoundError:
        print(f"File not found: {file_path}")

# Concatenate all dataframes into a single dataframe
all_HD_data = pd.concat(HD_data_list)

# Group by 'day_number' and calculate the mean for each column (except 'day_number')
average_HD_data = all_HD_data.groupby('day_number').mean().reset_index()

# Optionally, you can save the average data to a CSV file
average_HD_data.to_csv("X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/averaged/stage1_HD_female_average.csv", index=False)

# Print the averaged data
print(average_HD_data)
# Out:
#     day_number      total
# 0          1.0  11.333333
# 1          2.0  26.333333
# 2          3.0  33.666667
# 3          4.0  24.333333
# 4          5.0  23.666667
# 5          6.0  40.000000
# 6          7.0  30.333333
# 7          8.0  64.333333
# 8          9.0  72.000000
# 9         10.0  12.000000
# 10        11.0  48.000000
# 11        12.0  92.000000
# 12        13.0  72.000000

# %%
plot_averaged(average_HD_data, condition="HD", nogo = "FALSE", export_path_nogo=f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/exported_figures/stage1_female_HD_averaged_lick_rates.png", dpi=300)

# %% [markdown]
# # WT averaged

# %%
# List to hold dataframes
WT_data_list = []

# Load the .npy data for each mouse (HD)
for mouse in WT_mouse:
    file_path = f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/lick_rate_stage1_{mouse}.npy"
    try:
        # Load the .npy file into a numpy array
        WT_data = np.load(file_path)
        
        # Create a DataFrame from the data
        WT_df = pd.DataFrame(WT_data, columns=['day_number', 'total'])
        
        # Append the dataframe to the list
        WT_data_list.append(WT_df)
    except FileNotFoundError:
        print(f"File not found: {file_path}")

# Concatenate all dataframes into a single dataframe
all_WT_data = pd.concat(WT_data_list)

# Group by 'day_number' and calculate the mean for each column (except 'day_number')
average_WT_data = all_WT_data.groupby('day_number').mean().reset_index()

# Optionally, you can save the average data to a CSV file
average_WT_data.to_csv("X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/averaged/stage1_WT_female_average.csv", index=False)

# Print the averaged data
print(average_WT_data)
# Out:
#    day_number  total
# 0         1.0   23.0
# 1         2.0   62.0
# 2         3.0   39.0
# 3         4.0   62.5
# 4         5.0   59.0
# 5         6.0   39.5
# 6         7.0   47.0
# 7         8.0   60.0
# 8         9.0   90.0

# %%
plot_averaged(average_WT_data, condition="WT", nogo = "FALSE", export_path_nogo=f"X:/RaymondLab/1_Kai/3_processed_data/7_lick_rate_csv/exported_figures/stage1_female_WT_averaged_lick_rates.png", dpi=300)
