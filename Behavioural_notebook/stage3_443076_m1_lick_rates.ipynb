# %% [markdown]
# # stage3_443076_m1 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total)

# %%
stage = "stage3"
folder = select_folder(stage)
file_data, directory = folder[0], folder[1]
lick_rate = licking(file_data, stage)
# Out:
# Selected folder: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day10_2024-03-15_12-56-25_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day11_2024-04-09_13-09-06_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day12_2024-04-10_13-46-18_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day1_2024-02-23_15-04-27_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day2_2024-02-24_10-30-33_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day3_2024-02-27_16-18-38_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day4_2024-02-28_16-36-46_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day5_2024-03-06_12-18-42_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day6_2024-03-07_12-37-32_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day7_2024-03-08_17-12-22_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day8_2024-03-13_12-44-43_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443076/stage3_443076_m1/lick_rates\443076_m1_stage3_day9_2024-03-14_15-50-06_data.txt
# Processing complete.
# Stage 3 day 10 success left: 58.139534883720934%, success right:28.07017543859649%, fail: left stim right lick
# total successful trials 41.0
# Stage 3 day 11 success left: 16.3265306122449%, success right:58.82352941176471%, fail: left stim right lick
# total successful trials 38.0
# Stage 3 day 12 success left: 29.411764705882355%, success right:75.0%, fail: left stim right lick
# total successful trials 44.0
# Stage 3 day 1 success left: 1.2195121951219512%, success right:94.44444444444444%, fail: left stim right lick
# total successful trials 18.0
# Stage 3 day 2 success left: 1.1764705882352942%, success right:100.0%, fail: left stim right lick
# total successful trials 16.0
# Stage 3 day 3 success left: 93.33333333333333%, success right:2.3529411764705883%, fail: left stim right lick
# total successful trials 16.0
# Stage 3 day 4 success left: 36.76470588235294%, success right:43.75%, fail: left stim right lick
# total successful trials 39.0
# Stage 3 day 5 success left: 0.0%, success right:100.0%, fail: left stim right lick
# total successful trials 15.151515151515152
# Stage 3 day 6 success left: 36.36363636363637%, success right:33.33333333333333%, fail: left stim right lick
# total successful trials 35.0
# Stage 3 day 7 success left: 68.18181818181817%, success right:15.384615384615385%, fail: left stim right lick
# total successful trials 27.0
# Stage 3 day 8 success left: 25.31645569620253%, success right:76.19047619047619%, fail: left stim right lick
# total successful trials 36.0
# Stage 3 day 9 success left: 24.137931034482758%, success right:57.14285714285714%, fail: left stim right lick
# total successful trials 38.0

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)
