# %% [markdown]
# # stage3_443996_m5 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total)

# %%
stage = "stage3"
folder = select_folder(stage)
file_data, directory = folder[0], folder[1]
lick_rate = licking(file_data, stage)
# Out:
# Selected folder: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day10_2024-04-11_15-47-15_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day11_2024-04-12_13-44-24_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day12_2024-04-15_12-11-41_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day13_2024-04-16_12-59-37_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day14_2024-04-17_13-38-16_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day15_2024-04-18_11-45-00_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day16_2024-04-19_11-59-13_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day17_2024-04-23_16-11-41_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day1_2024-02-28_14-55-45_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day2_2024-03-06_13-18-12_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day3_2024-03-07_12-05-58_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day4_2024-03-08_16-18-56_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day5_2024-03-13_13-40-08_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day6_2024-03-14_16-24-48_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day7_2024-03-15_13-41-01_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day8_2024-04-09_13-34-13_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage3_443996_m5/lick_rate\443996_m5_stage3_day9_2024-04-10_14-45-16_data.txt
# Processing complete.
# Stage 3 day 10 success left: 94.87179487179486%, success right:4.918032786885246%, fail: left stim right lick
# total successful trials 39.99999999999999
# Stage 3 day 11 success left: 4.477611940298507%, success right:84.84848484848484%, fail: left stim right lick
# total successful trials 31.0
# Stage 3 day 12 success left: 97.2972972972973%, success right:1.5873015873015872%, fail: left stim right lick
# total successful trials 37.00000000000001
# Stage 3 day 13 success left: 0.0%, success right:93.10344827586206%, fail: left stim right lick
# total successful trials 27.0
# Stage 3 day 14 success left: 1.5625%, success right:97.22222222222221%, fail: left stim right lick
# total successful trials 35.99999999999999
# Stage 3 day 15 success left: 0.0%, success right:90.9090909090909%, fail: left stim right lick
# total successful trials 30.0
# Stage 3 day 16 success left: 0.0%, success right:97.77777777777777%, fail: left stim right lick
# total successful trials 44.0
# Stage 3 day 17 success left: 0.0%, success right:96.7741935483871%, fail: left stim right lick
# total successful trials 30.0
# Stage 3 day 1 success left: 0.0%, success right:100.0%, fail: left stim right lick
# total successful trials 18.0
# Stage 3 day 2 success left: 0.0%, success right:95.0%, fail: left stim right lick
# total successful trials 19.0
# Stage 3 day 3 success left: 28.169014084507044%, success right:72.41379310344827%, fail: left stim right lick
# total successful trials 41.0
# Stage 3 day 4 success left: 51.28205128205128%, success right:37.704918032786885%, fail: left stim right lick
# total successful trials 43.0
# Stage 3 day 5 success left: 77.77777777777779%, success right:2.73972602739726%, fail: left stim right lick
# total successful trials 23.0
# Stage 3 day 6 success left: 16.216216216216218%, success right:65.38461538461539%, fail: left stim right lick
# total successful trials 28.999999999999996
# Stage 3 day 7 success left: 9.722222222222223%, success right:82.14285714285714%, fail: left stim right lick
# total successful trials 30.0
# Stage 3 day 8 success left: 3.0303030303030303%, success right:91.17647058823529%, fail: left stim right lick
# total successful trials 33.0
# Stage 3 day 9 success left: 71.05263157894737%, success right:12.903225806451612%, fail: left stim right lick
# total successful trials 35.0

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)
