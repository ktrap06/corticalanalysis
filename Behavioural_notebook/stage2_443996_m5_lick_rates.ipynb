# %% [markdown]
# # stage2_443996_m5 lick rates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile
import cv2
from PIL import Image
import plotly.express as px
import imagecodecs
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import filedialog
import os

from functions_lick_rates import (licked_txt,
                                    load_files_from_folder,
                                    select_folder,
                                    licking,
                                    plot_array,
                                    plot_fail,
                                    plot_total)

# %%
stage = "stage2"
folder = select_folder(stage)
file_data, directory = folder[0], folder[1]
lick_rate = licking(file_data, stage)
# Out:
# Selected folder: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage2_443996_m5/lick_rates
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage2_443996_m5/lick_rates\443996_m5_stage2_day1_2024-02-23_13-19-06_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage2_443996_m5/lick_rates\443996_m5_stage2_day2_2024-02-24_12-00-51_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage2_443996_m5/lick_rates\443996_m5_stage2_day3_2024-02-26_13-47-04_data.txt
# Loading file: X:/Raymond Lab/1_Kai/2_Pi_data/1_first_cohort/443996/stage2_443996_m5/lick_rates\443996_m5_stage2_day4_2024-02-27_15-24-17_data.txt
# Processing complete.
# Stage 2 day 1 reached left lick rate of 79.59183673469387%, and right lick rate of 88.23529411764706%
# total successful trials 84.0
# Stage 2 day 2 reached left lick rate of 96.36363636363636%, and right lick rate of 100.0%
# total successful trials 98.0
# Stage 2 day 3 reached left lick rate of 100.0%, and right lick rate of 100.0%
# total successful trials 100.0
# Stage 2 day 4 reached left lick rate of 86.53846153846155%, and right lick rate of 95.83333333333334%
# total successful trials 91.0

# %%
mouseID = directory.split('/')[6]
export_path = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}LR.png"
export_path_total = f"X:/Raymond Lab/1_Kai/3_processed_data/3_lick_rates/{stage}/{mouseID}_total.png"
plot = plot_array(sorted(lick_rate),stage, export_path)

# %%
if stage == "stage3":
    plot2 = plot_fail(sorted(lick_rate),stage)

# %%
if stage == "stage2" or "stage3":
    plot_total(sorted(lick_rate),stage, export_path_total)
